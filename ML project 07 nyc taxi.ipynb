# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
os.chdir(r"C:\Users\User\Downloads\ml")

# %%
os.listdir()
# Out:
# ['1st model.ipynb',
#  '2. Linear Regression (1).pdf',
#  'covid19_sample.csv',
#  'Crop_Recommendation_Model.ipynb',
#  'data',
#  'DecisionTreeTheory.ipynb',
#  'Diabatic-checkpoint.ipynb',
#  'Diabatic.ipynb',
#  'DiabeticData.zip',
#  'Ensemble-checkpoint.ipynb',
#  'Ensemble.ipynb',
#  'KC house data.ipynb',
#  'LinearRegressionCarSales.ipynb',
#  'Loan Data linear reg. SAhil (1) (1).ipynb',
#  'LogReg_Default.ipynb',
#  'nyc taxi.ipynb',
#  'Project 5 car data-checkpoint.ipynb',
#  'project work.ipynb',
#  'pyplot.rar',
#  'sonu Loan Data linear reg. loan data.ipynb',
#  'yellow_tripdata_2022-06.parquet']

# %%
taxi=pd.read_parquet('yellow_tripdata_2022-06.parquet')

# %%
taxi.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-06-01 00:25:41   2022-06-01 00:48:22              1.0
# 1         1  2022-06-01 00:44:40   2022-06-01 01:01:48              1.0
# 2         2  2022-06-01 00:23:07   2022-06-01 00:39:50              1.0
# 3         1  2022-06-01 00:25:53   2022-06-01 00:57:06              2.0
# 4         1  2022-06-01 00:23:58   2022-06-01 00:33:43              0.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          11.00         1.0                  N            70            48
# 1           4.20         1.0                  N           170           226
# 2           9.49         1.0                  N           264           113
# 3          12.10         1.0                  N           132            17
# 4           1.80         1.0                  N           140           163
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         32.0   3.00      0.5        2.00          6.55
# 1             1         14.0   3.00      0.5        0.00          0.00
# 2             1         26.0   0.50      0.5        5.00          6.55
# 3             2         37.0   1.75      0.5        0.00          0.00
# 4             1          9.0   3.00      0.5        2.55          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    0.3         44.35                   2.5         0.00
# 1                    0.3         17.80                   2.5         0.00
# 2                    0.3         42.60                   2.5         1.25
# 3                    0.3         39.55                   0.0         1.25
# 4                    0.3         15.35                   2.5         0.00

# %%
from sklearn.model_selection import train_test_split
taxi,_=train_test_split(taxi,test_size=.98,random_state=0)

# %%
taxi.shape #3.5 million
# Out:
# (71162, 19)

# %%
taxi['VendorID'].value_counts()
# Out:
# 2    50189
# 1    20830
# 6      143
# Name: VendorID, dtype: int64

# %%
def univariate_cat(data,x):  
    missing=data[x].isnull().sum()  
    unique_cnt=data[x].nunique()  
    unique_cat=list(data[x].unique())  
    f1=pd.DataFrame(data[x].value_counts(dropna=False))  
    f1.rename(columns={x:'count'},inplace=True)  
    f2=pd.DataFrame(data[x].value_counts(normalize=True))  
    f2.rename(columns={x:'percentage'},inplace=True)  
    f2['percentage']=(f2['percentage']*100).round(2).astype(str)+'%'  
    ff=pd.concat([f1,f2],axis=1)  
    print(f"Total missing values : {missing}\n")  
    print(f"Total count of unique categories: {unique_cnt}\n")  
    print(f"Unique categories :\n{unique_cat}")  
    print(f'Value count and %\n:',ff) 
    sns.countplot(data=data,x=x) 
    plt.show()

# %%
univariate_cat(data=taxi,x='VendorID')
# Out:
# Total missing values : 0
#
# Total count of unique categories: 3
#
# Unique categories :
# [2, 1, 6]
# Value count and %
# :    count percentage
# 2  50189     70.53%
# 1  20830     29.27%
# 6    143       0.2%

# %%
taxi['VendorID']=taxi['VendorID'].replace([5,6],'others')

# %%
taxi['VendorID'].unique()
# Out:
# array([2, 1, 'others'], dtype=object)

# %%
taxi.dtypes[taxi.dtypes=='object']
# Out:
# VendorID              object
# store_and_fwd_flag    object
# dtype: object

# %%
univariate_cat(data=taxi,x='store_and_fwd_flag')
# Out:
# Total missing values : 2660
#
# Total count of unique categories: 2
#
# Unique categories :
# ['N', None, 'Y']
# Value count and %
# :       count percentage
# N     67674     98.79%
# None   2660        NaN
# Y       828      1.21%

# %%
taxi['store_and_fwd_flag']=taxi['store_and_fwd_flag'].replace(np.nan,'other')

# %%
taxi.isnull().sum()
# Out:
# VendorID                    0
# tpep_pickup_datetime        0
# tpep_dropoff_datetime       0
# passenger_count          2660
# trip_distance               0
# RatecodeID               2660
# store_and_fwd_flag          0
# PULocationID                0
# DOLocationID                0
# payment_type                0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# tolls_amount                0
# improvement_surcharge       0
# total_amount                0
# congestion_surcharge     2660
# airport_fee              2660
# dtype: int64

# %%
# 1= Standard rate
# 2=JFK
# 3=Newark
# 4=Nassau or Westchester
# 5=Negotiated fare
# 6=Group ride

# %%
taxi['RatecodeID']=taxi['RatecodeID'].map({1:'Standard_rate',2:'JFK',3:'Newark',4:'Nassau_or_Westchester',
                                          5:'Negotiated_fare',6:'Group_ride',99:'other'})

# %%
univariate_cat(data=taxi,x='RatecodeID')
# Out:
# Total missing values : 2660
#
# Total count of unique categories: 6
#
# Unique categories :
# ['Standard_rate', nan, 'Negotiated_fare', 'JFK', 'Newark', 'Nassau_or_Westchester', 'other']
# Value count and %
# :                        count percentage
# Standard_rate          64553     94.24%
# JFK                     2826      4.13%
# NaN                     2660        NaN
# Negotiated_fare          612      0.89%
# Newark                   217      0.32%
# other                    206       0.3%
# Nassau_or_Westchester     88      0.13%

# %%
taxi['RatecodeID']=taxi['RatecodeID'].replace(np.nan,'other')

# %%
taxi['RatecodeID'].value_counts(dropna=False)
# Out:
# Standard_rate            64553
# other                     2866
# JFK                       2826
# Negotiated_fare            612
# Newark                     217
# Nassau_or_Westchester       88
# Name: RatecodeID, dtype: int64

# %%
taxi
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 11293          2  2022-06-01 08:48:20   2022-06-01 09:00:30              1.0
# 3241804        2  2022-06-29 12:30:59   2022-06-29 13:20:10              1.0
# 2122208        1  2022-06-19 01:03:50   2022-06-19 01:27:44              1.0
# 645015         2  2022-06-06 17:16:57   2022-06-06 17:35:51              1.0
# 1752107        2  2022-06-15 22:09:34   2022-06-15 22:28:03              1.0
# ...          ...                  ...                   ...              ...
# 2249467        2  2022-06-20 14:41:39   2022-06-20 14:59:51              1.0
# 963395         2  2022-06-09 10:34:13   2022-06-09 10:43:23              1.0
# 2215104        1  2022-06-20 06:49:59   2022-06-20 07:06:14              0.0
# 1484405        2  2022-06-13 19:18:27   2022-06-13 19:22:38              3.0
# 305711         2  2022-06-03 16:32:58   2022-06-03 16:37:03              1.0
#
#          trip_distance     RatecodeID store_and_fwd_flag  PULocationID  \
# 11293             1.75  Standard_rate                  N           143
# 3241804           9.16  Standard_rate                  N           143
# 2122208           5.00  Standard_rate                  N           249
# 645015            3.02  Standard_rate                  N           230
# 1752107           3.53  Standard_rate                  N            90
# ...                ...            ...                ...           ...
# 2249467           4.49  Standard_rate                  N           263
# 963395            1.51  Standard_rate                  N            48
# 2215104           8.90  Standard_rate                  N           140
# 1484405           0.90  Standard_rate                  N           230
# 305711            0.87  Standard_rate                  N           236
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 11293              48             1          9.5    0.0      0.5        2.00
# 3241804            95             2         36.0    0.0      0.5        0.00
# 2122208            80             1         20.0    3.0      0.5        2.00
# 645015            113             1         13.5    1.0      0.5        1.78
# 1752107           237             1         14.5    0.5      0.5        2.74
# ...               ...           ...          ...    ...      ...         ...
# 2249467           234             1         17.0    0.0      0.5        2.00
# 963395            246             1          8.5    0.0      0.5        2.36
# 2215104           138             1         25.5    2.5      0.5        5.30
# 1484405           163             2          5.0    1.0      0.5        0.00
# 305711            236             2          5.0    1.0      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 11293            0.00                    0.3         14.80
# 3241804          0.00                    0.3         39.30
# 2122208          0.00                    0.3         25.80
# 645015           0.00                    0.3         19.58
# 1752107          0.00                    0.3         21.04
# ...               ...                    ...           ...
# 2249467          0.00                    0.3         22.30
# 963395           0.00                    0.3         14.16
# 2215104          6.55                    0.3         40.65
# 1484405          0.00                    0.3          9.30
# 305711           0.00                    0.3          9.30
#
#          congestion_surcharge  airport_fee
# 11293                     2.5          0.0
# 3241804                   2.5          0.0
# 2122208                   2.5          0.0
# 645015                    2.5          0.0
# 1752107                   2.5          0.0
# ...                       ...          ...
# 2249467                   2.5          0.0
# 963395                    2.5          0.0
# 2215104                   2.5          0.0
# 1484405                   2.5          0.0
# 305711                    2.5          0.0
#
# [71162 rows x 19 columns]

# %%
univariate_cat(data=taxi,x='payment_type')
# Out:
# Total missing values : 0
#
# Total count of unique categories: 5
#
# Unique categories :
# [1, 2, 0, 4, 3]
# Value count and %
# :    count percentage
# 1  53921     75.77%
# 2  13873     19.49%
# 0   2660      3.74%
# 3    363      0.51%
# 4    345      0.48%

# %%
# 1= Credit card
# 2= Cash
# 3= No charge
# 4= Dispute
# 5= Unknown
# 6= Voided trip

# %%
taxi['payment_type']=taxi['payment_type'].map({1:'Credit_card',2:'Cash',3:'No_charge',4:'Dispute',0:'Unknown'})

# %%
taxi['payment_type'].value_counts()
# Out:
# Credit_card    53921
# Cash           13873
# Unknown         2660
# No_charge        363
# Dispute          345
# Name: payment_type, dtype: int64

# %%
taxi.head()
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 11293          2  2022-06-01 08:48:20   2022-06-01 09:00:30              1.0
# 3241804        2  2022-06-29 12:30:59   2022-06-29 13:20:10              1.0
# 2122208        1  2022-06-19 01:03:50   2022-06-19 01:27:44              1.0
# 645015         2  2022-06-06 17:16:57   2022-06-06 17:35:51              1.0
# 1752107        2  2022-06-15 22:09:34   2022-06-15 22:28:03              1.0
#
#          trip_distance     RatecodeID store_and_fwd_flag  PULocationID  \
# 11293             1.75  Standard_rate                  N           143
# 3241804           9.16  Standard_rate                  N           143
# 2122208           5.00  Standard_rate                  N           249
# 645015            3.02  Standard_rate                  N           230
# 1752107           3.53  Standard_rate                  N            90
#
#          DOLocationID payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 11293              48  Credit_card          9.5    0.0      0.5        2.00
# 3241804            95         Cash         36.0    0.0      0.5        0.00
# 2122208            80  Credit_card         20.0    3.0      0.5        2.00
# 645015            113  Credit_card         13.5    1.0      0.5        1.78
# 1752107           237  Credit_card         14.5    0.5      0.5        2.74
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 11293             0.0                    0.3         14.80
# 3241804           0.0                    0.3         39.30
# 2122208           0.0                    0.3         25.80
# 645015            0.0                    0.3         19.58
# 1752107           0.0                    0.3         21.04
#
#          congestion_surcharge  airport_fee
# 11293                     2.5          0.0
# 3241804                   2.5          0.0
# 2122208                   2.5          0.0
# 645015                    2.5          0.0
# 1752107                   2.5          0.0

# %%
univariate_cat(data=taxi,x='passenger_count') #discrete
# Out:
# Total missing values : 2660
#
# Total count of unique categories: 7
#
# Unique categories :
# [1.0, 2.0, nan, 3.0, 0.0, 4.0, 5.0, 6.0]
# Value count and %
# :      count percentage
# 1.0  50763      74.1%
# 2.0  10331     15.08%
# 3.0   2815      4.11%
# NaN   2660        NaN
# 0.0   1327      1.94%
# 4.0   1278      1.87%
# 5.0   1150      1.68%
# 6.0    838      1.22%

# %%
def univariate_num(data,x):
    """one numerical variable analysis """
    missing=data[x].isnull().sum()
    min1=round(data[x].min(), 2)
    max1=round(data[x].max(), 2)
    mean=round(data[x].mean(), 2)
    var=round(data[x].var(), 2)
    std=round(data[x].std(),2)
    range1=round(max1-min1, 2)
    q1=round(data[x].quantile(.25), 2)
    q2=round(data[x].quantile(.5),2)
    q3=round(data[x].quantile(.75), 2)
    skew=round( data[x].skew(), 2)
    kurt=round(data[x].kurt(), 2)
    myvalue={"missing":missing, "min":min1, "max":max1, "mean":mean,
             "var":var,"std":std, "range":range1,"q1":q1, "q2":q2,"q3":q3,
            "skewness":skew, "kurtosis":kurt}
    sns.histplot(data[x])
    plt.show()
    sns.boxplot(data=data, y=data[x])
    plt.show()
    return myvalue

# %%
univariate_num(data=taxi,x='passenger_count')
# Out:
# {'missing': 2660,
#  'min': 0.0,
#  'max': 6.0,
#  'mean': 1.4,
#  'var': 0.92,
#  'std': 0.96,
#  'range': 6.0,
#  'q1': 1.0,
#  'q2': 1.0,
#  'q3': 1.0,
#  'skewness': 2.74,
#  'kurtosis': 8.32}

# %%
taxi
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 11293          2  2022-06-01 08:48:20   2022-06-01 09:00:30              1.0
# 3241804        2  2022-06-29 12:30:59   2022-06-29 13:20:10              1.0
# 2122208        1  2022-06-19 01:03:50   2022-06-19 01:27:44              1.0
# 645015         2  2022-06-06 17:16:57   2022-06-06 17:35:51              1.0
# 1752107        2  2022-06-15 22:09:34   2022-06-15 22:28:03              1.0
# ...          ...                  ...                   ...              ...
# 2249467        2  2022-06-20 14:41:39   2022-06-20 14:59:51              1.0
# 963395         2  2022-06-09 10:34:13   2022-06-09 10:43:23              1.0
# 2215104        1  2022-06-20 06:49:59   2022-06-20 07:06:14              0.0
# 1484405        2  2022-06-13 19:18:27   2022-06-13 19:22:38              3.0
# 305711         2  2022-06-03 16:32:58   2022-06-03 16:37:03              1.0
#
#          trip_distance     RatecodeID store_and_fwd_flag  PULocationID  \
# 11293             1.75  Standard_rate                  N           143
# 3241804           9.16  Standard_rate                  N           143
# 2122208           5.00  Standard_rate                  N           249
# 645015            3.02  Standard_rate                  N           230
# 1752107           3.53  Standard_rate                  N            90
# ...                ...            ...                ...           ...
# 2249467           4.49  Standard_rate                  N           263
# 963395            1.51  Standard_rate                  N            48
# 2215104           8.90  Standard_rate                  N           140
# 1484405           0.90  Standard_rate                  N           230
# 305711            0.87  Standard_rate                  N           236
#
#          DOLocationID payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 11293              48  Credit_card          9.5    0.0      0.5        2.00
# 3241804            95         Cash         36.0    0.0      0.5        0.00
# 2122208            80  Credit_card         20.0    3.0      0.5        2.00
# 645015            113  Credit_card         13.5    1.0      0.5        1.78
# 1752107           237  Credit_card         14.5    0.5      0.5        2.74
# ...               ...          ...          ...    ...      ...         ...
# 2249467           234  Credit_card         17.0    0.0      0.5        2.00
# 963395            246  Credit_card          8.5    0.0      0.5        2.36
# 2215104           138  Credit_card         25.5    2.5      0.5        5.30
# 1484405           163         Cash          5.0    1.0      0.5        0.00
# 305711            236         Cash          5.0    1.0      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 11293            0.00                    0.3         14.80
# 3241804          0.00                    0.3         39.30
# 2122208          0.00                    0.3         25.80
# 645015           0.00                    0.3         19.58
# 1752107          0.00                    0.3         21.04
# ...               ...                    ...           ...
# 2249467          0.00                    0.3         22.30
# 963395           0.00                    0.3         14.16
# 2215104          6.55                    0.3         40.65
# 1484405          0.00                    0.3          9.30
# 305711           0.00                    0.3          9.30
#
#          congestion_surcharge  airport_fee
# 11293                     2.5          0.0
# 3241804                   2.5          0.0
# 2122208                   2.5          0.0
# 645015                    2.5          0.0
# 1752107                   2.5          0.0
# ...                       ...          ...
# 2249467                   2.5          0.0
# 963395                    2.5          0.0
# 2215104                   2.5          0.0
# 1484405                   2.5          0.0
# 305711                    2.5          0.0
#
# [71162 rows x 19 columns]

# %%
taxi.drop(columns=['DOLocationID','PULocationID'],inplace=True)

# %%
taxi[taxi['fare_amount']<2.5].shape
# Out:
# (525, 17)

# %%
taxi1=taxi[taxi['fare_amount']>=2.5]

# %%
taxi1.shape
# Out:
# (70637, 17)

# %%
taxi1.dtypes[taxi1.dtypes!='object'].index
# Out:
# Index(['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count',
#        'trip_distance', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
univariate_num(data=taxi1,x='extra')
# Out:
# {'missing': 0,
#  'min': 0.0,
#  'max': 8.25,
#  'mean': 1.03,
#  'var': 1.58,
#  'std': 1.26,
#  'range': 8.25,
#  'q1': 0.0,
#  'q2': 0.5,
#  'q3': 2.5,
#  'skewness': 1.14,
#  'kurtosis': 0.75}

# %%
taxi1[taxi1['extra']==0].shape
# Out:
# (28530, 17)

# %%
taxi1['fare_amount'].describe(percentiles=[.7,.8,.9,.95,.96,.97,.98,.99]).T
# Out:
# count    70637.000000
# mean        15.515271
# std         47.583181
# min          2.500000
# 50%         10.500000
# 70%         15.000000
# 80%         19.500000
# 90%         32.000000
# 95%         52.000000
# 96%         52.000000
# 97%         52.000000
# 98%         52.000000
# 99%         64.000000
# max       6977.000000
# Name: fare_amount, dtype: float64

# %%
taxi[taxi['fare_amount']>=5000]
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1028144        2  2022-06-09 19:39:42   2022-06-09 20:20:12              1.0
# 3201244        2  2022-06-28 23:46:52   2022-06-29 00:09:25              1.0
# 557418         2  2022-06-05 19:03:17   2022-06-05 19:35:56              1.0
#
#          trip_distance     RatecodeID store_and_fwd_flag payment_type  \
# 1028144          14.89  Standard_rate                  N         Cash
# 3201244           3.27  Standard_rate                  N         Cash
# 557418            6.51  Standard_rate                  N         Cash
#
#          fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 1028144       6977.0    1.0      0.5         0.0           0.0
# 3201244       6966.5    0.5      0.5         0.0           0.0
# 557418        6975.5    0.0      0.5         0.0           0.0
#
#          improvement_surcharge  total_amount  congestion_surcharge  \
# 1028144                    0.3       6981.30                   2.5
# 3201244                    0.3       6970.30                   2.5
# 557418                     0.3       6977.55                   0.0
#
#          airport_fee
# 1028144         0.00
# 3201244         0.00
# 557418          1.25

# %%
univariate_num(data=taxi1,x='mta_tax')
# Out:
# {'missing': 0,
#  'min': 0.0,
#  'max': 2.78,
#  'mean': 0.49,
#  'var': 0.0,
#  'std': 0.05,
#  'range': 2.78,
#  'q1': 0.5,
#  'q2': 0.5,
#  'q3': 0.5,
#  'skewness': -6.5,
#  'kurtosis': 188.41}

# %%
taxi1['mta_tax'].describe(percentiles=[.7,.8,.9,.95,.96,.97,.98,.99]).T
# Out:
# count    70637.000000
# mean         0.494919
# std          0.051908
# min          0.000000
# 50%          0.500000
# 70%          0.500000
# 80%          0.500000
# 90%          0.500000
# 95%          0.500000
# 96%          0.500000
# 97%          0.500000
# 98%          0.500000
# 99%          0.500000
# max          2.780000
# Name: mta_tax, dtype: float64

# %%
univariate_num(data=taxi1,x='tip_amount')
# Out:
# {'missing': 0,
#  'min': 0.0,
#  'max': 98.0,
#  'mean': 2.81,
#  'var': 10.4,
#  'std': 3.22,
#  'range': 98.0,
#  'q1': 1.0,
#  'q2': 2.2,
#  'q3': 3.45,
#  'skewness': 3.82,
#  'kurtosis': 44.22}

# %%
univariate_num(data=taxi1,x='tolls_amount')
# Out:
# {'missing': 0,
#  'min': 0.0,
#  'max': 52.0,
#  'mean': 0.57,
#  'var': 4.33,
#  'std': 2.08,
#  'range': 52.0,
#  'q1': 0.0,
#  'q2': 0.0,
#  'q3': 0.0,
#  'skewness': 4.8,
#  'kurtosis': 36.86}

# %%
univariate_num(data=taxi1,x='improvement_surcharge')
# Out:
# {'missing': 0,
#  'min': 0.0,
#  'max': 0.3,
#  'mean': 0.3,
#  'var': 0.0,
#  'std': 0.0,
#  'range': 0.3,
#  'q1': 0.3,
#  'q2': 0.3,
#  'q3': 0.3,
#  'skewness': -76.71,
#  'kurtosis': 5881.83}

# %%
taxi1.drop(columns=['improvement_surcharge'],inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\4218148775.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1.drop(columns=['improvement_surcharge'],inplace=True)

# %%
taxi1
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 11293          2  2022-06-01 08:48:20   2022-06-01 09:00:30              1.0
# 3241804        2  2022-06-29 12:30:59   2022-06-29 13:20:10              1.0
# 2122208        1  2022-06-19 01:03:50   2022-06-19 01:27:44              1.0
# 645015         2  2022-06-06 17:16:57   2022-06-06 17:35:51              1.0
# 1752107        2  2022-06-15 22:09:34   2022-06-15 22:28:03              1.0
# ...          ...                  ...                   ...              ...
# 2249467        2  2022-06-20 14:41:39   2022-06-20 14:59:51              1.0
# 963395         2  2022-06-09 10:34:13   2022-06-09 10:43:23              1.0
# 2215104        1  2022-06-20 06:49:59   2022-06-20 07:06:14              0.0
# 1484405        2  2022-06-13 19:18:27   2022-06-13 19:22:38              3.0
# 305711         2  2022-06-03 16:32:58   2022-06-03 16:37:03              1.0
#
#          trip_distance     RatecodeID store_and_fwd_flag payment_type  \
# 11293             1.75  Standard_rate                  N  Credit_card
# 3241804           9.16  Standard_rate                  N         Cash
# 2122208           5.00  Standard_rate                  N  Credit_card
# 645015            3.02  Standard_rate                  N  Credit_card
# 1752107           3.53  Standard_rate                  N  Credit_card
# ...                ...            ...                ...          ...
# 2249467           4.49  Standard_rate                  N  Credit_card
# 963395            1.51  Standard_rate                  N  Credit_card
# 2215104           8.90  Standard_rate                  N  Credit_card
# 1484405           0.90  Standard_rate                  N         Cash
# 305711            0.87  Standard_rate                  N         Cash
#
#          fare_amount  extra  mta_tax  tip_amount  tolls_amount  total_amount  \
# 11293            9.5    0.0      0.5        2.00          0.00         14.80
# 3241804         36.0    0.0      0.5        0.00          0.00         39.30
# 2122208         20.0    3.0      0.5        2.00          0.00         25.80
# 645015          13.5    1.0      0.5        1.78          0.00         19.58
# 1752107         14.5    0.5      0.5        2.74          0.00         21.04
# ...              ...    ...      ...         ...           ...           ...
# 2249467         17.0    0.0      0.5        2.00          0.00         22.30
# 963395           8.5    0.0      0.5        2.36          0.00         14.16
# 2215104         25.5    2.5      0.5        5.30          6.55         40.65
# 1484405          5.0    1.0      0.5        0.00          0.00          9.30
# 305711           5.0    1.0      0.5        0.00          0.00          9.30
#
#          congestion_surcharge  airport_fee
# 11293                     2.5          0.0
# 3241804                   2.5          0.0
# 2122208                   2.5          0.0
# 645015                    2.5          0.0
# 1752107                   2.5          0.0
# ...                       ...          ...
# 2249467                   2.5          0.0
# 963395                    2.5          0.0
# 2215104                   2.5          0.0
# 1484405                   2.5          0.0
# 305711                    2.5          0.0
#
# [70637 rows x 16 columns]

# %%
univariate_num(data=taxi1,x='total_amount')
# Out:
# {'missing': 0,
#  'min': 3.3,
#  'max': 6981.3,
#  'mean': 22.45,
#  'var': 2374.85,
#  'std': 48.73,
#  'range': 6978.0,
#  'q1': 12.36,
#  'q2': 16.3,
#  'q3': 23.3,
#  'skewness': 123.63,
#  'kurtosis': 17609.46}

# %%
univariate_num(data=taxi1,x='congestion_surcharge')
# Out:
# {'missing': 2658,
#  'min': 0.0,
#  'max': 2.5,
#  'mean': 2.31,
#  'var': 0.44,
#  'std': 0.67,
#  'range': 2.5,
#  'q1': 2.5,
#  'q2': 2.5,
#  'q3': 2.5,
#  'skewness': -3.17,
#  'kurtosis': 8.08}

# %%
univariate_num(data=taxi1,x='airport_fee')
# Out:
# {'missing': 2658,
#  'min': 0.0,
#  'max': 1.25,
#  'mean': 0.1,
#  'var': 0.11,
#  'std': 0.34,
#  'range': 1.25,
#  'q1': 0.0,
#  'q2': 0.0,
#  'q3': 0.0,
#  'skewness': 3.15,
#  'kurtosis': 7.92}

# %%
taxi1[taxi1['airport_fee']==0].shape
# Out:
# (62683, 16)

# %% [markdown]
# ## feature engineering

# %%
taxi1.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
taxi['tpep_pickup_datetime'].min()
# Out:
# Timestamp('2002-10-21 12:53:50')

# %%
taxi['tpep_pickup_datetime'].max()
# Out:
# Timestamp('2022-07-01 00:36:12')

# %%
# Date: month,weekend/weekday,public_holiday,time of pickup (early morniing,morning,afternoon,evening,night,late night)
# two date: duration,

# %%
taxi1['month']=taxi1['tpep_pickup_datetime'].dt.month
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\2902181035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['month']=taxi1['tpep_pickup_datetime'].dt.month

# %%
taxi1['year']=taxi1['tpep_pickup_datetime'].dt.year
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\2214737363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['year']=taxi1['tpep_pickup_datetime'].dt.year

# %%
taxi1['year'].value_counts()
# Out:
# 2022    70630
# 2002        7
# Name: year, dtype: int64

# %%
taxi1['week_of_day']=taxi1['tpep_pickup_datetime'].dt.dayofweek
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\582882557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['week_of_day']=taxi1['tpep_pickup_datetime'].dt.dayofweek

# %%
taxi1['month'].value_counts()
# Out:
# 6     70627
# 10        7
# 7         2
# 5         1
# Name: month, dtype: int64

# %%
tax1=taxi1[taxi1['month']==6]
tax1=taxi1[taxi1['year']==2022]

# %%
taxi1['isweekend']=np.where(taxi1['week_of_day'].isin([5,6]),1,0)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\3520564055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['isweekend']=np.where(taxi1['week_of_day'].isin([5,6]),1,0)

# %%
taxi1
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 11293          2  2022-06-01 08:48:20   2022-06-01 09:00:30              1.0
# 3241804        2  2022-06-29 12:30:59   2022-06-29 13:20:10              1.0
# 2122208        1  2022-06-19 01:03:50   2022-06-19 01:27:44              1.0
# 645015         2  2022-06-06 17:16:57   2022-06-06 17:35:51              1.0
# 1752107        2  2022-06-15 22:09:34   2022-06-15 22:28:03              1.0
# ...          ...                  ...                   ...              ...
# 2249467        2  2022-06-20 14:41:39   2022-06-20 14:59:51              1.0
# 963395         2  2022-06-09 10:34:13   2022-06-09 10:43:23              1.0
# 2215104        1  2022-06-20 06:49:59   2022-06-20 07:06:14              0.0
# 1484405        2  2022-06-13 19:18:27   2022-06-13 19:22:38              3.0
# 305711         2  2022-06-03 16:32:58   2022-06-03 16:37:03              1.0
#
#          trip_distance     RatecodeID store_and_fwd_flag payment_type  \
# 11293             1.75  Standard_rate                  N  Credit_card
# 3241804           9.16  Standard_rate                  N         Cash
# 2122208           5.00  Standard_rate                  N  Credit_card
# 645015            3.02  Standard_rate                  N  Credit_card
# 1752107           3.53  Standard_rate                  N  Credit_card
# ...                ...            ...                ...          ...
# 2249467           4.49  Standard_rate                  N  Credit_card
# 963395            1.51  Standard_rate                  N  Credit_card
# 2215104           8.90  Standard_rate                  N  Credit_card
# 1484405           0.90  Standard_rate                  N         Cash
# 305711            0.87  Standard_rate                  N         Cash
#
#          fare_amount  extra  mta_tax  tip_amount  tolls_amount  total_amount  \
# 11293            9.5    0.0      0.5        2.00          0.00         14.80
# 3241804         36.0    0.0      0.5        0.00          0.00         39.30
# 2122208         20.0    3.0      0.5        2.00          0.00         25.80
# 645015          13.5    1.0      0.5        1.78          0.00         19.58
# 1752107         14.5    0.5      0.5        2.74          0.00         21.04
# ...              ...    ...      ...         ...           ...           ...
# 2249467         17.0    0.0      0.5        2.00          0.00         22.30
# 963395           8.5    0.0      0.5        2.36          0.00         14.16
# 2215104         25.5    2.5      0.5        5.30          6.55         40.65
# 1484405          5.0    1.0      0.5        0.00          0.00          9.30
# 305711           5.0    1.0      0.5        0.00          0.00          9.30
#
#          congestion_surcharge  airport_fee  month  year  week_of_day  \
# 11293                     2.5          0.0      6  2022            2
# 3241804                   2.5          0.0      6  2022            2
# 2122208                   2.5          0.0      6  2022            6
# 645015                    2.5          0.0      6  2022            0
# 1752107                   2.5          0.0      6  2022            2
# ...                       ...          ...    ...   ...          ...
# 2249467                   2.5          0.0      6  2022            0
# 963395                    2.5          0.0      6  2022            3
# 2215104                   2.5          0.0      6  2022            0
# 1484405                   2.5          0.0      6  2022            0
# 305711                    2.5          0.0      6  2022            4
#
#          isweekend
# 11293            0
# 3241804          0
# 2122208          1
# 645015           0
# 1752107          0
# ...            ...
# 2249467          0
# 963395           0
# 2215104          0
# 1484405          0
# 305711           0
#
# [70637 rows x 20 columns]

# %%
taxi1['day']=taxi1['tpep_pickup_datetime'].dt.day
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\1902479973.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['day']=taxi1['tpep_pickup_datetime'].dt.day

# %%
def day_cut(x):
    if x<=10:
        return 'starting_of_month'
    elif x>10 and x<=20:
        return 'mid_of_month'
    else:
        return 'End_of_month'

# %%
taxi1['day_cat']=taxi1['day'].apply(lambda a:day_cut(a))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\2197867038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['day_cat']=taxi1['day'].apply(lambda a:day_cut(a))

# %%
taxi1['day_cat'].value_counts()
# Out:
# starting_of_month    24395
# mid_of_month         23261
# End_of_month         22981
# Name: day_cat, dtype: int64

# %%
taxi1['day']
# Out:
# 11293       1
# 3241804    29
# 2122208    19
# 645015      6
# 1752107    15
#            ..
# 2249467    20
# 963395      9
# 2215104    20
# 1484405    13
# 305711      3
# Name: day, Length: 70637, dtype: int64

# %%
taxi1['hour']=taxi1['tpep_pickup_datetime'].dt.hour
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\2673408928.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['hour']=taxi1['tpep_pickup_datetime'].dt.hour

# %%
taxi1['hour'].value_counts()
# Out:
# 18    5002
# 17    4698
# 19    4608
# 15    4323
# 14    4309
# 16    4248
# 13    3966
# 12    3855
# 21    3792
# 20    3765
# 11    3677
# 22    3587
# 10    3333
# 9     3038
# 23    2869
# 8     2746
# 0     2060
# 7     2041
# 1     1313
# 6     1076
# 2      880
# 3      574
# 5      489
# 4      388
# Name: hour, dtype: int64

# %%
taxi1['minute']=taxi1['tpep_pickup_datetime'].dt.minute
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\3817820385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['minute']=taxi1['tpep_pickup_datetime'].dt.minute

# %%
# early morning:4-8
# morning:8-12
# even:16-20
# night:20-24
# mid nig-

# %%
def hour_category(x):
    if x>=4 and x<8:
        return 'early_morning'
    elif x>=8 and x<12:
        return 'morning'
    elif x>=12 and x<16:
        return 'Afternoon'
    elif x>=16 and x<20:
        return 'Evening'
    elif x>=20 and x<24:
        return 'night'
    elif x>=0 and x<4:
        return 'midnight'
    else:
        return 'unkown'

# %%
taxi1['hours_cat']=taxi1['hour'].apply(lambda a:hour_category(a))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\3250730328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['hours_cat']=taxi1['hour'].apply(lambda a:hour_category(a))

# %%
taxi1['hours_cat'].value_counts(normalize=True)
# Out:
# Evening          0.262695
# Afternoon        0.232923
# night            0.198380
# morning          0.181123
# midnight         0.068335
# early_morning    0.056543
# Name: hours_cat, dtype: float64

# %%
taxi1['duration']=(taxi1['tpep_dropoff_datetime']-taxi1['tpep_pickup_datetime'])*24
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\2613786903.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['duration']=(taxi1['tpep_dropoff_datetime']-taxi1['tpep_pickup_datetime'])*24

# %%
taxi1['duration'].min()
# Out:
# Timedelta('-41472 days +10:51:26.290448384')

# %%
taxi1['airport']=np.where(taxi1['airport_fee']==0,0,1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\3751949944.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['airport']=np.where(taxi1['airport_fee']==0,0,1)

# %%
taxi1.head()
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 11293          2  2022-06-01 08:48:20   2022-06-01 09:00:30              1.0
# 3241804        2  2022-06-29 12:30:59   2022-06-29 13:20:10              1.0
# 2122208        1  2022-06-19 01:03:50   2022-06-19 01:27:44              1.0
# 645015         2  2022-06-06 17:16:57   2022-06-06 17:35:51              1.0
# 1752107        2  2022-06-15 22:09:34   2022-06-15 22:28:03              1.0
#
#          trip_distance     RatecodeID store_and_fwd_flag payment_type  \
# 11293             1.75  Standard_rate                  N  Credit_card
# 3241804           9.16  Standard_rate                  N         Cash
# 2122208           5.00  Standard_rate                  N  Credit_card
# 645015            3.02  Standard_rate                  N  Credit_card
# 1752107           3.53  Standard_rate                  N  Credit_card
#
#          fare_amount  extra  ...  year  week_of_day  isweekend  day  \
# 11293            9.5    0.0  ...  2022            2          0    1
# 3241804         36.0    0.0  ...  2022            2          0   29
# 2122208         20.0    3.0  ...  2022            6          1   19
# 645015          13.5    1.0  ...  2022            0          0    6
# 1752107         14.5    0.5  ...  2022            2          0   15
#
#                    day_cat  hour  minute  hours_cat        duration  airport
# 11293    starting_of_month     8      48    morning 0 days 04:52:00        0
# 3241804       End_of_month    12      30  Afternoon 0 days 19:40:24        0
# 2122208       mid_of_month     1       3   midnight 0 days 09:33:36        0
# 645015   starting_of_month    17      16    Evening 0 days 07:33:36        0
# 1752107       mid_of_month    22       9      night 0 days 07:23:36        0
#
# [5 rows x 27 columns]

# %%
def fare_cut(x):
    if x<=10:
        return '(0,10]'
    elif x>10 and x<=20:
        return '[10-20]'
    elif x>20 and x<=30:
        return '(20,30]'
    elif x>30 and x<=40:
        return '(30,40]'
    elif x>40 and x<=50:
        return '(40,50]'
    elif x>50 and x<=60:
        return '(50,60]'
    elif x>60 and x<=70:
        return '(60,70]'
    elif x>70 and x<=80:
        return '(70,80]'
    elif x>80 and x<=90:
        return '(80,90]'
    elif x>90 and x<=100:
        return '(90,100]'
    else:
        return '100+'

# %%
taxi1['fare_cat']=taxi1['total_amount'].apply(lambda a:fare_cut(a))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\4110563148.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['fare_cat']=taxi1['total_amount'].apply(lambda a:fare_cut(a))

# %%
sns.histplot(taxi1['fare_cat'])
# Out:
# <AxesSubplot:xlabel='fare_cat', ylabel='Count'>

# %%
taxi1['duration']=((taxi1['tpep_dropoff_datetime']-taxi1['tpep_pickup_datetime'])/pd.Timedelta(minutes=1))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\3602048154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi1['duration']=((taxi1['tpep_dropoff_datetime']-taxi1['tpep_pickup_datetime'])/pd.Timedelta(minutes=1))

# %%
taxi1['duration'].max()
# Out:
# 10321946.083333334

# %%
def duration_cat(x):
    if x<15:
        return 'duration_bt_0_15m'
    elif x<30:
        return 'duration_bt_0_30m'
    elif x>=30 and x<60:
        return 'duration_bt_30_60m'
    elif x>=60 and x<120:
        return 'duration_bt_60_120m'
    else:
        return 'duration_morethan_120m'

# %%
tax1['duration_Cat']=taxi1['duration'].apply(lambda y:duration_cat(y))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\268102782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tax1['duration_Cat']=taxi1['duration'].apply(lambda y:duration_cat(y))

# %%
tax1['duration_Cat'].value_counts()
# Out:
# duration_bt_0_15m         41743
# duration_bt_0_30m         20679
# duration_bt_30_60m         6757
# duration_bt_60_120m        1350
# duration_morethan_120m      101
# Name: duration_Cat, dtype: int64

# %% [markdown]
# ### missing values

# %%
taxi1.isnull().sum()
# Out:
# VendorID                    0
# tpep_pickup_datetime        0
# tpep_dropoff_datetime       0
# passenger_count          2658
# trip_distance               0
# RatecodeID                  0
# store_and_fwd_flag          0
# payment_type                0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# tolls_amount                0
# total_amount                0
# congestion_surcharge     2658
# airport_fee              2658
# month                       0
# year                        0
# week_of_day                 0
# isweekend                   0
# day                         0
# day_cat                     0
# hour                        0
# minute                      0
# hours_cat                   0
# duration                    0
# airport                     0
# fare_cat                    0
# dtype: int64

# %%
taxi1[taxi1.isnull()]
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 11293        NaN                  NaT                   NaT              NaN
# 3241804      NaN                  NaT                   NaT              NaN
# 2122208      NaN                  NaT                   NaT              NaN
# 645015       NaN                  NaT                   NaT              NaN
# 1752107      NaN                  NaT                   NaT              NaN
# ...          ...                  ...                   ...              ...
# 2249467      NaN                  NaT                   NaT              NaN
# 963395       NaN                  NaT                   NaT              NaN
# 2215104      NaN                  NaT                   NaT              NaN
# 1484405      NaN                  NaT                   NaT              NaN
# 305711       NaN                  NaT                   NaT              NaN
#
#          trip_distance RatecodeID store_and_fwd_flag payment_type  \
# 11293              NaN        NaN                NaN          NaN
# 3241804            NaN        NaN                NaN          NaN
# 2122208            NaN        NaN                NaN          NaN
# 645015             NaN        NaN                NaN          NaN
# 1752107            NaN        NaN                NaN          NaN
# ...                ...        ...                ...          ...
# 2249467            NaN        NaN                NaN          NaN
# 963395             NaN        NaN                NaN          NaN
# 2215104            NaN        NaN                NaN          NaN
# 1484405            NaN        NaN                NaN          NaN
# 305711             NaN        NaN                NaN          NaN
#
#          fare_amount  extra  ...  week_of_day  isweekend  day  day_cat  hour  \
# 11293            NaN    NaN  ...          NaN        NaN  NaN      NaN   NaN
# 3241804          NaN    NaN  ...          NaN        NaN  NaN      NaN   NaN
# 2122208          NaN    NaN  ...          NaN        NaN  NaN      NaN   NaN
# 645015           NaN    NaN  ...          NaN        NaN  NaN      NaN   NaN
# 1752107          NaN    NaN  ...          NaN        NaN  NaN      NaN   NaN
# ...              ...    ...  ...          ...        ...  ...      ...   ...
# 2249467          NaN    NaN  ...          NaN        NaN  NaN      NaN   NaN
# 963395           NaN    NaN  ...          NaN        NaN  NaN      NaN   NaN
# 2215104          NaN    NaN  ...          NaN        NaN  NaN      NaN   NaN
# 1484405          NaN    NaN  ...          NaN        NaN  NaN      NaN   NaN
# 305711           NaN    NaN  ...          NaN        NaN  NaN      NaN   NaN
#
#          minute  hours_cat  duration  airport  fare_cat
# 11293       NaN        NaN       NaN      NaN       NaN
# 3241804     NaN        NaN       NaN      NaN       NaN
# 2122208     NaN        NaN       NaN      NaN       NaN
# 645015      NaN        NaN       NaN      NaN       NaN
# 1752107     NaN        NaN       NaN      NaN       NaN
# ...         ...        ...       ...      ...       ...
# 2249467     NaN        NaN       NaN      NaN       NaN
# 963395      NaN        NaN       NaN      NaN       NaN
# 2215104     NaN        NaN       NaN      NaN       NaN
# 1484405     NaN        NaN       NaN      NaN       NaN
# 305711      NaN        NaN       NaN      NaN       NaN
#
# [70637 rows x 28 columns]

# %%
temp0=taxi1[taxi1['passenger_count'].isnull()]

# %%
taxi2=taxi1.dropna()

# %%
taxi2.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# total_amount             0
# congestion_surcharge     0
# airport_fee              0
# month                    0
# year                     0
# week_of_day              0
# isweekend                0
# day                      0
# day_cat                  0
# hour                     0
# minute                   0
# hours_cat                0
# duration                 0
# airport                  0
# fare_cat                 0
# dtype: int64

# %% [markdown]
# ### outliers

# %%
taxi2.describe(percentiles=[.01,.02,.03,.04,.05,.25,.5,.75,.9,.95,.96,.97,.98,.99]).T
# Out:
#                         count         mean           std     min           1%  \
# passenger_count       67979.0     1.398667      0.959772     0.0     0.000000
# trip_distance         67979.0     3.541001      4.782481     0.0     0.000000
# fare_amount           67979.0    15.271909     48.395777     2.5     3.500000
# extra                 67979.0     1.069589      1.263509     0.0     0.000000
# mta_tax               67979.0     0.494904      0.052045     0.0     0.000000
# tip_amount            67979.0     2.765501      3.209152     0.0     0.000000
# tolls_amount          67979.0     0.562389      2.062854     0.0     0.000000
# total_amount          67979.0    22.169912     49.522266     3.3     6.800000
# congestion_surcharge  67979.0     2.307624      0.666286     0.0     0.000000
# airport_fee           67979.0     0.097383      0.335033     0.0     0.000000
# month                 67979.0     6.000427      0.041128     5.0     6.000000
# year                  67979.0  2021.997941      0.202942  2002.0  2022.000000
# week_of_day           67979.0     2.936907      1.863570     0.0     0.000000
# isweekend             67979.0     0.243928      0.429453     0.0     0.000000
# day                   67979.0    15.242545      8.633228     1.0     1.000000
# hour                  67979.0    14.198959      5.789239     0.0     0.000000
# minute                67979.0    29.618206     17.319824     0.0     0.000000
# duration              67979.0   169.811886  39588.933533     0.0     0.366667
# airport               67979.0     0.077906      0.268026     0.0     0.000000
#
#                                2%      3%           4%           5%  \
# passenger_count          1.000000     1.0     1.000000     1.000000
# trip_distance            0.240000     0.4     0.470000     0.510000
# fare_amount              4.000000     4.0     4.500000     4.500000
# extra                    0.000000     0.0     0.000000     0.000000
# mta_tax                  0.500000     0.5     0.500000     0.500000
# tip_amount               0.000000     0.0     0.000000     0.000000
# tolls_amount             0.000000     0.0     0.000000     0.000000
# total_amount             7.800000     8.3     8.760000     8.800000
# congestion_surcharge     0.000000     0.0     0.000000     0.000000
# airport_fee              0.000000     0.0     0.000000     0.000000
# month                    6.000000     6.0     6.000000     6.000000
# year                  2022.000000  2022.0  2022.000000  2022.000000
# week_of_day              0.000000     0.0     0.000000     0.000000
# isweekend                0.000000     0.0     0.000000     0.000000
# day                      1.000000     1.0     2.000000     2.000000
# hour                     0.000000     1.0     1.000000     2.000000
# minute                   1.000000     1.0     2.000000     3.000000
# duration                 1.916667     2.6     3.033333     3.416667
# airport                  0.000000     0.0     0.000000     0.000000
#
#                               25%          50%      75%      90%          95%  \
# passenger_count          1.000000     1.000000     1.00     2.00     3.000000
# trip_distance            1.130000     1.900000     3.55     9.02    15.491000
# fare_amount              7.000000    10.500000    16.50    31.20    52.000000
# extra                    0.000000     0.500000     2.50     3.00     3.500000
# mta_tax                  0.500000     0.500000     0.50     0.50     0.500000
# tip_amount               1.000000     2.160000     3.36     5.66     9.550000
# tolls_amount             0.000000     0.000000     0.00     0.00     6.550000
# total_amount            12.350000    15.960000    22.88    43.35    63.100000
# congestion_surcharge     2.500000     2.500000     2.50     2.50     2.500000
# airport_fee              0.000000     0.000000     0.00     0.00     1.250000
# month                    6.000000     6.000000     6.00     6.00     6.000000
# year                  2022.000000  2022.000000  2022.00  2022.00  2022.000000
# week_of_day              1.000000     3.000000     4.00     6.00     6.000000
# isweekend                0.000000     0.000000     0.00     1.00     1.000000
# day                      8.000000    15.000000    23.00    27.00    29.000000
# hour                    10.000000    15.000000    19.00    21.00    22.000000
# minute                  15.000000    30.000000    45.00    54.00    56.000000
# duration                 7.616667    12.533333    20.20    32.00    43.666667
# airport                  0.000000     0.000000     0.00     0.00     1.000000
#
#                           96%          97%          98%       99%  \
# passenger_count          4.00     4.000000     5.000000     6.000
# trip_distance           17.09    17.876600    18.680000    20.260
# fare_amount             52.00    52.000000    52.000000    62.500
# extra                    3.50     3.500000     3.500000     3.750
# mta_tax                  0.50     0.500000     0.500000     0.500
# tip_amount              10.27    11.960000    12.620000    15.000
# tolls_amount             6.55     6.550000     6.550000     6.550
# total_amount            67.85    73.100000    75.720000    81.120
# congestion_surcharge     2.50     2.500000     2.500000     2.500
# airport_fee              1.25     1.250000     1.250000     1.250
# month                    6.00     6.000000     6.000000     6.000
# year                  2022.00  2022.000000  2022.000000  2022.000
# week_of_day              6.00     6.000000     6.000000     6.000
# isweekend                1.00     1.000000     1.000000     1.000
# day                     29.00    30.000000    30.000000    30.000
# hour                    23.00    23.000000    23.000000    23.000
# minute                  57.00    58.000000    58.000000    59.000
# duration                47.70    52.799667    59.916667    71.498
# airport                  1.00     1.000000     1.000000     1.000
#
#                                max
# passenger_count       6.000000e+00
# trip_distance         4.101700e+02
# fare_amount           6.977000e+03
# extra                 8.250000e+00
# mta_tax               2.780000e+00
# tip_amount            9.800000e+01
# tolls_amount          5.200000e+01
# total_amount          6.981300e+03
# congestion_surcharge  2.500000e+00
# airport_fee           1.250000e+00
# month                 1.000000e+01
# year                  2.022000e+03
# week_of_day           6.000000e+00
# isweekend             1.000000e+00
# day                   3.100000e+01
# hour                  2.300000e+01
# minute                5.900000e+01
# duration              1.032195e+07
# airport               1.000000e+00

# %%
# taxi

# %%
taxi2.drop(columns=['tpep_pickup_datetime','tpep_dropoff_datetime'],inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11028\175399171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taxi2.drop(columns=['tpep_pickup_datetime','tpep_dropoff_datetime'],inplace=True)

# %%
obj_var=taxi2.dtypes[taxi2.dtypes=='object'].index

# %%
num_var=taxi2.dtypes[taxi2.dtypes!='object'].index

# %%
taxi_num=taxi2[num_var]
taxi_obj=taxi2[obj_var]

# %%
def outiliers(x):
    x=x.clip(upper=x.quantile(.99))
#     x=x.clip(lower=x.quantile(.01))
    return x

# %%
taxi_num=taxi_num.apply(outiliers)

# %%
taxi_num
# Out:
#          passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 11293                1.0           1.75          9.5    0.0      0.5
# 3241804              1.0           9.16         36.0    0.0      0.5
# 2122208              1.0           5.00         20.0    3.0      0.5
# 645015               1.0           3.02         13.5    1.0      0.5
# 1752107              1.0           3.53         14.5    0.5      0.5
# ...                  ...            ...          ...    ...      ...
# 2249467              1.0           4.49         17.0    0.0      0.5
# 963395               1.0           1.51          8.5    0.0      0.5
# 2215104              0.0           8.90         25.5    2.5      0.5
# 1484405              3.0           0.90          5.0    1.0      0.5
# 305711               1.0           0.87          5.0    1.0      0.5
#
#          tip_amount  tolls_amount  total_amount  congestion_surcharge  \
# 11293          2.00          0.00         14.80                   2.5
# 3241804        0.00          0.00         39.30                   2.5
# 2122208        2.00          0.00         25.80                   2.5
# 645015         1.78          0.00         19.58                   2.5
# 1752107        2.74          0.00         21.04                   2.5
# ...             ...           ...           ...                   ...
# 2249467        2.00          0.00         22.30                   2.5
# 963395         2.36          0.00         14.16                   2.5
# 2215104        5.30          6.55         40.65                   2.5
# 1484405        0.00          0.00          9.30                   2.5
# 305711         0.00          0.00          9.30                   2.5
#
#          airport_fee  month  year  week_of_day  isweekend   day  hour  minute  \
# 11293            0.0    6.0  2022            2          0   1.0     8      48
# 3241804          0.0    6.0  2022            2          0  29.0    12      30
# 2122208          0.0    6.0  2022            6          1  19.0     1       3
# 645015           0.0    6.0  2022            0          0   6.0    17      16
# 1752107          0.0    6.0  2022            2          0  15.0    22       9
# ...              ...    ...   ...          ...        ...   ...   ...     ...
# 2249467          0.0    6.0  2022            0          0  20.0    14      41
# 963395           0.0    6.0  2022            3          0   9.0    10      34
# 2215104          0.0    6.0  2022            0          0  20.0     6      49
# 1484405          0.0    6.0  2022            0          0  13.0    19      18
# 305711           0.0    6.0  2022            4          0   3.0    16      32
#
#           duration  airport
# 11293    12.166667        0
# 3241804  49.183333        0
# 2122208  23.900000        0
# 645015   18.900000        0
# 1752107  18.483333        0
# ...            ...      ...
# 2249467  18.200000        0
# 963395    9.166667        0
# 2215104  16.250000        0
# 1484405   4.183333        0
# 305711    4.083333        0
#
# [67979 rows x 19 columns]

# %%
taxi_num.describe(percentiles=[.7,.8,.9,.95,.96,.97,.98,.99]).T
# Out:
#                         count         mean        std     min          50%  \
# passenger_count       67979.0     1.398667   0.959772     0.0     1.000000
# trip_distance         67979.0     3.496592   4.290748     0.0     1.900000
# fare_amount           67979.0    14.729483  12.488385     2.5    10.500000
# extra                 67979.0     1.056353   1.220956     0.0     0.500000
# mta_tax               67979.0     0.494837   0.050548     0.0     0.500000
# tip_amount            67979.0     2.722777   2.912769     0.0     2.160000
# tolls_amount          67979.0     0.515386   1.760761     0.0     0.000000
# total_amount          67979.0    21.585429  15.946435     3.3    15.960000
# congestion_surcharge  67979.0     2.307624   0.666286     0.0     2.500000
# airport_fee           67979.0     0.097383   0.335033     0.0     0.000000
# month                 67979.0     5.999985   0.003835     5.0     6.000000
# year                  67979.0  2021.997941   0.202942  2002.0  2022.000000
# week_of_day           67979.0     2.936907   1.863570     0.0     3.000000
# isweekend             67979.0     0.243928   0.429453     0.0     0.000000
# day                   67979.0    15.242531   8.633202     1.0    15.000000
# hour                  67979.0    14.198959   5.789239     0.0    15.000000
# minute                67979.0    29.618206  17.319824     0.0    30.000000
# duration              67979.0    16.180514  13.031534     0.0    12.533333
# airport               67979.0     0.077906   0.268026     0.0     0.000000
#
#                               70%          80%      90%          95%      96%  \
# passenger_count          1.000000     2.000000     2.00     3.000000     4.00
# trip_distance            3.030000     4.360000     9.02    15.491000    17.09
# fare_amount             14.500000    19.000000    31.20    52.000000    52.00
# extra                    1.000000     2.500000     3.00     3.500000     3.50
# mta_tax                  0.500000     0.500000     0.50     0.500000     0.50
# tip_amount               3.060000     3.850000     5.66     9.550000    10.27
# tolls_amount             0.000000     0.000000     0.00     6.550000     6.55
# total_amount            20.800000    25.800000    43.35    63.100000    67.85
# congestion_surcharge     2.500000     2.500000     2.50     2.500000     2.50
# airport_fee              0.000000     0.000000     0.00     1.250000     1.25
# month                    6.000000     6.000000     6.00     6.000000     6.00
# year                  2022.000000  2022.000000  2022.00  2022.000000  2022.00
# week_of_day              4.000000     5.000000     6.00     6.000000     6.00
# isweekend                0.000000     1.000000     1.00     1.000000     1.00
# day                     21.000000    24.000000    27.00    29.000000    29.00
# hour                    18.000000    19.000000    21.00    22.000000    23.00
# minute                  42.000000    48.000000    54.00    56.000000    57.00
# duration                18.183333    22.716667    32.00    43.666667    47.70
# airport                  0.000000     0.000000     0.00     1.000000     1.00
#
#                               97%          98%         99%       max
# passenger_count          4.000000     5.000000     6.00000     6.000
# trip_distance           17.876600    18.680000    20.26000    20.260
# fare_amount             52.000000    52.000000    62.50000    62.500
# extra                    3.500000     3.500000     3.75000     3.750
# mta_tax                  0.500000     0.500000     0.50000     0.500
# tip_amount              11.960000    12.620000    15.00000    15.000
# tolls_amount             6.550000     6.550000     6.55000     6.550
# total_amount            73.100000    75.720000    81.12000    81.120
# congestion_surcharge     2.500000     2.500000     2.50000     2.500
# airport_fee              1.250000     1.250000     1.25000     1.250
# month                    6.000000     6.000000     6.00000     6.000
# year                  2022.000000  2022.000000  2022.00000  2022.000
# week_of_day              6.000000     6.000000     6.00000     6.000
# isweekend                1.000000     1.000000     1.00000     1.000
# day                     30.000000    30.000000    30.00000    30.000
# hour                    23.000000    23.000000    23.00000    23.000
# minute                  58.000000    58.000000    59.00000    59.000
# duration                52.799667    59.916667    71.48656    71.498
# airport                  1.000000     1.000000     1.00000     1.000

# %%
taxi_final=pd.concat([taxi_num,taxi_obj],axis=1)

# %%
taxi_final
# Out:
#          passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 11293                1.0           1.75          9.5    0.0      0.5
# 3241804              1.0           9.16         36.0    0.0      0.5
# 2122208              1.0           5.00         20.0    3.0      0.5
# 645015               1.0           3.02         13.5    1.0      0.5
# 1752107              1.0           3.53         14.5    0.5      0.5
# ...                  ...            ...          ...    ...      ...
# 2249467              1.0           4.49         17.0    0.0      0.5
# 963395               1.0           1.51          8.5    0.0      0.5
# 2215104              0.0           8.90         25.5    2.5      0.5
# 1484405              3.0           0.90          5.0    1.0      0.5
# 305711               1.0           0.87          5.0    1.0      0.5
#
#          tip_amount  tolls_amount  total_amount  congestion_surcharge  \
# 11293          2.00          0.00         14.80                   2.5
# 3241804        0.00          0.00         39.30                   2.5
# 2122208        2.00          0.00         25.80                   2.5
# 645015         1.78          0.00         19.58                   2.5
# 1752107        2.74          0.00         21.04                   2.5
# ...             ...           ...           ...                   ...
# 2249467        2.00          0.00         22.30                   2.5
# 963395         2.36          0.00         14.16                   2.5
# 2215104        5.30          6.55         40.65                   2.5
# 1484405        0.00          0.00          9.30                   2.5
# 305711         0.00          0.00          9.30                   2.5
#
#          airport_fee  ...  minute   duration  airport  VendorID  \
# 11293            0.0  ...      48  12.166667        0         2
# 3241804          0.0  ...      30  49.183333        0         2
# 2122208          0.0  ...       3  23.900000        0         1
# 645015           0.0  ...      16  18.900000        0         2
# 1752107          0.0  ...       9  18.483333        0         2
# ...              ...  ...     ...        ...      ...       ...
# 2249467          0.0  ...      41  18.200000        0         2
# 963395           0.0  ...      34   9.166667        0         2
# 2215104          0.0  ...      49  16.250000        0         1
# 1484405          0.0  ...      18   4.183333        0         2
# 305711           0.0  ...      32   4.083333        0         2
#
#             RatecodeID  store_and_fwd_flag  payment_type            day_cat  \
# 11293    Standard_rate                   N   Credit_card  starting_of_month
# 3241804  Standard_rate                   N          Cash       End_of_month
# 2122208  Standard_rate                   N   Credit_card       mid_of_month
# 645015   Standard_rate                   N   Credit_card  starting_of_month
# 1752107  Standard_rate                   N   Credit_card       mid_of_month
# ...                ...                 ...           ...                ...
# 2249467  Standard_rate                   N   Credit_card       mid_of_month
# 963395   Standard_rate                   N   Credit_card  starting_of_month
# 2215104  Standard_rate                   N   Credit_card       mid_of_month
# 1484405  Standard_rate                   N          Cash       mid_of_month
# 305711   Standard_rate                   N          Cash  starting_of_month
#
#              hours_cat fare_cat
# 11293          morning  [10-20]
# 3241804      Afternoon  (30,40]
# 2122208       midnight  (20,30]
# 645015         Evening  [10-20]
# 1752107          night  (20,30]
# ...                ...      ...
# 2249467      Afternoon  (20,30]
# 963395         morning  [10-20]
# 2215104  early_morning  (40,50]
# 1484405        Evening   (0,10]
# 305711         Evening   (0,10]
#
# [67979 rows x 26 columns]

# %% [markdown]
# ### Multicollinarity

# %%
taxi_final.drop(columns=['month','year','fare_amount'],inplace=True)

# %%
cr=taxi_final.corr()
cr=cr[abs(cr)>0.7]

# %%
plt.figure(figsize=(11,6))
sns.heatmap(cr,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
taxi_final.drop(columns=['fare_cat'],inplace=True)

# %%
taxi_final.drop(columns=['airport_fee','week_of_day'],inplace=True)

# %% [markdown]
# ## Dummy creation

# %%
final=pd.get_dummies(data=taxi_final,drop_first=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)

# %%
final.head()
# Out:
#          passenger_count  trip_distance  extra  mta_tax  tip_amount  \
# 11293                1.0           1.75    0.0      0.5        2.00
# 3241804              1.0           9.16    0.0      0.5        0.00
# 2122208              1.0           5.00    3.0      0.5        2.00
# 645015               1.0           3.02    1.0      0.5        1.78
# 1752107              1.0           3.53    0.5      0.5        2.74
#
#          tolls_amount  total_amount  congestion_surcharge  isweekend   day  \
# 11293             0.0         14.80                   2.5          0   1.0
# 3241804           0.0         39.30                   2.5          0  29.0
# 2122208           0.0         25.80                   2.5          1  19.0
# 645015            0.0         19.58                   2.5          0   6.0
# 1752107           0.0         21.04                   2.5          0  15.0
#
#          ...  payment_type_Credit_card  payment_type_Dispute  \
# 11293    ...                         1                     0
# 3241804  ...                         0                     0
# 2122208  ...                         1                     0
# 645015   ...                         1                     0
# 1752107  ...                         1                     0
#
#          payment_type_No_charge  day_cat_mid_of_month  \
# 11293                         0                     0
# 3241804                       0                     0
# 2122208                       0                     1
# 645015                        0                     0
# 1752107                       0                     1
#
#          day_cat_starting_of_month  hours_cat_Evening  \
# 11293                            1                  0
# 3241804                          0                  0
# 2122208                          0                  0
# 645015                           1                  1
# 1752107                          0                  0
#
#          hours_cat_early_morning  hours_cat_midnight  hours_cat_morning  \
# 11293                          0                   0                  1
# 3241804                        0                   0                  0
# 2122208                        0                   1                  0
# 645015                         0                   0                  0
# 1752107                        0                   0                  0
#
#          hours_cat_night
# 11293                  0
# 3241804                0
# 2122208                0
# 645015                 0
# 1752107                1
#
# [5 rows x 31 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV,train_test_split,RandomizedSearchCV

# %%
y=final['total_amount']
x=final.drop('total_amount',axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=0)

# %%
# criterion:{'squared error','absolute error','poisson'}

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfr.score(x_train,y_train)
# Out:
# 0.9973614203456607

# %%
rfr.score(x_test,y_test)
# Out:
# 0.9843711837185126

# %%
predicted_train=rfr.predict(x_train)

# %%
np.mean((predicted_train-y_train)**2)
# Out:
# 0.672660520450993

# %%
pred_test=rfr.predict(x_test)
